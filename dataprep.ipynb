# %% [markdown]
# ### Merging the stock data and news info

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia=SentimentIntensityAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dataprep.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dataprep.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dataprep.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# ----> <a href='vscode-notebook-cell:/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dataprep.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> sia=SentimentIntensityAnalyzer()
#
# File ~/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/lib/python3.11/site-packages/nltk/sentiment/vader.py:340, in SentimentIntensityAnalyzer.__init__(self, lexicon_file)
#     336 def __init__(
#     337     self,
#     338     lexicon_file="sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt",
#     339 ):
# --> 340     self.lexicon_file = nltk.data.load(lexicon_file)
#     341     self.lexicon = self.make_lex_dict()
#     342     self.constants = VaderConstants()
#
# File ~/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/lib/python3.11/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/lib/python3.11/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource vader_lexicon not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('vader_lexicon')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt
#
#   Searched in:
#     - '/Users/zainulmustafa/nltk_data'
#     - '/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/nltk_data'
#     - '/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/share/nltk_data'
#     - '/Users/zainulmustafa/Workspace/sciengit/python/Stock-Prediction-using-News-Info-Sentiment/dvenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
df_news = pd.read_json('headlines_june.json',convert_dates=['Date'])
df_news = pd.DataFrame.from_records(df_news['news'])

df_news.head()
# Out:
#          Date                                          headlines
# 0  2011-01-01  Transporters threaten protest, hike in fares.P...
# 1  2011-01-02  Power sectorâ€™s payables cross Rs275bn mark.N...
# 2  2011-01-03  Sui cantonment turned into military college.De...
# 3  2011-01-04  Big loss to progressive forces, says Sherry.Bl...
# 4  2011-01-05  Naming new Punjab governor a test for Zardari....

# %%
df_news['Date'] = pd.to_datetime(df_news['Date'])
df_news['Date'] = df_news['Date'].dt.strftime('%d-%b-%Y')

df_bank = pd.read_csv('MCB_01012010_06122018.csv')
df_bank.head()
# Out:
#   Symbol         Date    Open    High     Low   Close   Volume
# 0    MCB  04-Jan-2010  219.60  220.40  215.20  215.95  2478180
# 1    MCB  05-Jan-2010  216.89  220.75  216.20  219.25  3720502
# 2    MCB  06-Jan-2010  220.05  225.00  220.05  223.40  5189731
# 3    MCB  07-Jan-2010  223.40  224.89  221.50  222.44  2032048
# 4    MCB  08-Jan-2010  223.00  223.25  219.50  220.42  1752809

# %%
df_news.head()
# Out:
#           Date                                          headlines
# 0  01-Jan-2011  Transporters threaten protest, hike in fares.P...
# 1  02-Jan-2011  Power sectorâ€™s payables cross Rs275bn mark.N...
# 2  03-Jan-2011  Sui cantonment turned into military college.De...
# 3  04-Jan-2011  Big loss to progressive forces, says Sherry.Bl...
# 4  05-Jan-2011  Naming new Punjab governor a test for Zardari....

# %%
df_merged = df_bank.merge(df_news,on='Date')
df_merged.head()
# Out:
#   Symbol         Date    Open    High     Low   Close   Volume  \
# 0    MCB  03-Jan-2011  226.00  227.00  221.50  223.32   646442
# 1    MCB  04-Jan-2011  223.32  229.50  223.32  227.97  1601540
# 2    MCB  05-Jan-2011  227.00  232.00  225.60  226.27  2181684
# 3    MCB  06-Jan-2011  227.00  227.65  224.20  226.16  1034935
# 4    MCB  07-Jan-2011  227.50  227.99  223.80  225.99  1247251
#
#                                            headlines
# 0  Sui cantonment turned into military college.De...
# 1  Big loss to progressive forces, says Sherry.Bl...
# 2  Naming new Punjab governor a test for Zardari....
# 3  Violence in Pakistan declines: US report.Power...
# 4  President vows to expose Taseerâ€™s killers.Be...

# %%
df_merged.tail()
# Out:
#      Symbol         Date    Open    High     Low   Close  Volume  \
# 1841    MCB  01-Jun-2018  202.44  207.00  202.44  205.67  646800
# 1842    MCB  04-Jun-2018  206.00  209.80  204.60  208.94  602100
# 1843    MCB  05-Jun-2018  207.44  213.85  207.00  212.82  632500
# 1844    MCB  06-Jun-2018  211.50  216.00  210.50  214.85  780100
# 1845    MCB  07-Jun-2018  215.10  216.00  213.00  213.32  214800
#
#                                               headlines
# 1841  5 devotees killed, 4 injured as speeding dumpe...
# 1842  ECP nullifies postings, transfers of officials...
# 1843  2 die, over 100 houses and shops damaged as st...
# 1844  MQM's Haider Abbas Rizvi returns from 'self-ex...
# 1845  Meet Hammad Safi, the 11-year-old motivational...

# %%
df_merged.shape
# Out:
# (1846, 8)

# %%
df_merged=df_merged[['Date','Open','High','Low','Close','Volume','headlines']]
df_merged.head()
# Out:
#           Date    Open    High     Low   Close   Volume  \
# 0  03-Jan-2011  226.00  227.00  221.50  223.32   646442
# 1  04-Jan-2011  223.32  229.50  223.32  227.97  1601540
# 2  05-Jan-2011  227.00  232.00  225.60  226.27  2181684
# 3  06-Jan-2011  227.00  227.65  224.20  226.16  1034935
# 4  07-Jan-2011  227.50  227.99  223.80  225.99  1247251
#
#                                            headlines
# 0  Sui cantonment turned into military college.De...
# 1  Big loss to progressive forces, says Sherry.Bl...
# 2  Naming new Punjab governor a test for Zardari....
# 3  Violence in Pakistan declines: US report.Power...
# 4  President vows to expose Taseerâ€™s killers.Be...

# %%
df_merged['compund']=''
df_merged['neg']=''
df_merged['neu']=''
df_merged['pos']=''

df_merged.head()
# Out:
#           Date    Open    High     Low   Close   Volume  \
# 0  03-Jan-2011  226.00  227.00  221.50  223.32   646442
# 1  04-Jan-2011  223.32  229.50  223.32  227.97  1601540
# 2  05-Jan-2011  227.00  232.00  225.60  226.27  2181684
# 3  06-Jan-2011  227.00  227.65  224.20  226.16  1034935
# 4  07-Jan-2011  227.50  227.99  223.80  225.99  1247251
#
#                                            headlines compund neg neu pos
# 0  Sui cantonment turned into military college.De...
# 1  Big loss to progressive forces, says Sherry.Bl...
# 2  Naming new Punjab governor a test for Zardari....
# 3  Violence in Pakistan declines: US report.Power...
# 4  President vows to expose Taseerâ€™s killers.Be...

# %%
for index,sentence in enumerate(df_merged['headlines']):
    ps=sia.polarity_scores(sentence)
    df_merged['compund'][index]=ps['compound']
    df_merged['neg'][index]=ps['neg']
    df_merged['neu'][index]=ps['neu']
    df_merged['pos'][index]=ps['pos']
#   break
# Out:
# d:\python362_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# d:\python362_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# d:\python362_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# d:\python362_64\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
final_df = df_merged[['Date','compund','neg','neu','pos','Open','High','Low','Close','Volume']]

# %%
final_df.head()
# Out:
#           Date compund    neg    neu    pos    Open    High     Low   Close  \
# 0  03-Jan-2011 -0.8934  0.172  0.746  0.082  226.00  227.00  221.50  223.32
# 1  04-Jan-2011 -0.6996  0.133  0.806   0.06  223.32  229.50  223.32  227.97
# 2  05-Jan-2011 -0.9442  0.319  0.638  0.044  227.00  232.00  225.60  226.27
# 3  06-Jan-2011 -0.7906  0.179  0.726  0.094  227.00  227.65  224.20  226.16
# 4  07-Jan-2011 -0.5859   0.14  0.766  0.094  227.50  227.99  223.80  225.99
#
#     Volume
# 0   646442
# 1  1601540
# 2  2181684
# 3  1034935
# 4  1247251

# %%
final_df.to_csv('final_data_mcb.csv',index=False)
